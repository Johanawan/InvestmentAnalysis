# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC', '^IXIC', '^GDAXI', '^DJI']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI         ^DJI
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059  6442.490234
# 1997-01-03  748.030029  1310.680054  2863.260010  6544.089844
# 1997-01-06  747.650024  1316.400024  2890.199951  6567.180176
# 1997-01-07  753.229980  1327.729980  2876.340088  6600.660156
# 1997-01-08  748.409973  1320.349976  2904.080078  6549.479980

# %%
ind_data.tail()
# Out:
#                   ^GSPC        ^IXIC        ^GDAXI          ^DJI
# Date
# 2019-02-28  2784.489990  7532.529785  11515.639648  25916.000000
# 2019-03-01  2803.689941  7595.350098  11601.679688  26026.320312
# 2019-03-04  2792.810059  7577.569824  11592.660156  25819.650391
# 2019-03-05  2789.649902  7576.359863  11620.740234  25806.630859
# 2019-03-06  2771.449951  7505.919922  11587.629883  25673.460938

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1

ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI      ^DJI
# Date
# 2019-02-28 -0.002826 -0.002910  0.002464 -0.002662
# 2019-03-01  0.006895  0.008340  0.007472  0.004257
# 2019-03-04 -0.003881 -0.002341 -0.000777 -0.007941
# 2019-03-05 -0.001132 -0.000160  0.002422 -0.000504
# 2019-03-06 -0.006524 -0.009297 -0.002849 -0.005160

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.077429
# ^IXIC     0.110343
# ^GDAXI    0.076966
# ^DJI      0.078152
# dtype: float64

# %%
tickers = ['PG', '^GSPC', '^DJI']

data_2 = pd.DataFrame()

for t in tickers:
    data_2[t] = wb.DataReader(t, data_source='yahoo', start='2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                    PG        ^GSPC          ^DJI
# Date
# 2019-02-28  98.550003  2784.489990  25916.000000
# 2019-03-01  98.440002  2803.689941  26026.320312
# 2019-03-04  98.870003  2792.810059  25819.650391
# 2019-03-05  99.089996  2789.649902  25806.630859
# 2019-03-06  98.930000  2771.449951  25673.460938

# %%
(data_2 / data_2.iloc[0] * 100).plot(figsize=(15,6));
plt.show()
